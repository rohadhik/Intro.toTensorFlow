# %%
# import the tensorflow library
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.0.0

# %%
# import libraries
import numpy as np
import keras
# Out:
# Using TensorFlow backend.

# %%
# define the input and output variables
x = np.array([-2.0, -1.0, 2.0, 4.0, 5.0, 7.0])
y = np.array([-13.0, -10.0, -1.0, 5.0, 8.0, 14.0])

# %%
# initialize the keras sequential model with one dense layer and one input
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
# train the model with optimizer and loss 
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# fit the model and train it with 500 epochs
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 6/6 [==============================] - 0s 8ms/step - loss: 75.2362
# Epoch 2/500
# 6/6 [==============================] - 0s 333us/step - loss: 50.5341
# Epoch 3/500
# 6/6 [==============================] - 0s 332us/step - loss: 39.2809
# Epoch 4/500
# 6/6 [==============================] - 0s 334us/step - loss: 33.9341
# Epoch 5/500
# 6/6 [==============================] - 0s 1ms/step - loss: 31.1867
# Epoch 6/500
# 6/6 [==============================] - 0s 333us/step - loss: 29.5888
# Epoch 7/500
# 6/6 [==============================] - 0s 500us/step - loss: 28.5043
# Epoch 8/500
# 6/6 [==============================] - 0s 333us/step - loss: 27.6542
# Epoch 9/500
# 6/6 [==============================] - 0s 499us/step - loss: 26.9158
# Epoch 10/500
# 6/6 [==============================] - 0s 1000us/step - loss: 26.2353
# Epoch 11/500
# 6/6 [==============================] - 0s 333us/step - loss: 25.5887
# Epoch 12/500
# ...

# %%
# model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# predict the new input 
model.predict([9.0])
# Out:
# array([[19.993275]], dtype=float32)

# %%
# predict another input
model.predict([40.0])
# Out:
# array([[112.91439]], dtype=float32)

# %%
# predict with multiple inputs
model.predict([10.0, 11.0, 15.0])
# Out:
# array([[22.99073 ],
#        [25.988186],
#        [37.97801 ]], dtype=float32)

# %% [markdown]
# #### This is also called as the Hello world program of the tensorflow keras sequential model.
# #### In this we used optimizer 'sgd' to optimize the result w.r.t loss function which is mean_squared_error by reducing the error.
